# %% [markdown]
# # Binary search

# %% [markdown]
# Binary search is a search algorithm used to find the position of a target value within a sorted array. It works by repeatedly dividing the search interval in half until the target value is found or the interval is empty. The search interval is halved by comparing the target element with the middle value of the search space

# %% [markdown]
# Conditions to apply Binary Search Algorithm in a Data Structure
# To apply Binary Search algorithm:
#
# The data structure must be sorted.
# Access to any element of the data structure should take constant time.

# %% [markdown]
# Binary Search Algorithm
# algorithm for Binary Search:
#
# Divide the search space into two halves by finding the middle index “mid”.
# Compare the middle element of the search space with the key.
# If the key is found at middle element, the process is terminated.
# If the key is not found at middle element, choose which half will be used as the next search space.
# If the key is smaller than the middle element, then the left side is used for next search.
# If the key is larger than the middle element, then the right side is used for next search.
# This process is continued until the key is found or the total search space is exhausted

# %%
# i - Iterative algorithm
def binary_search(arr,item):
    n=len(arr)
    low=0
    high= n-1
    arr.sort()
    while low<=high:
        mid=(low+high)//2
        if item == arr[mid]:
            return {"Your item in array is at index :",mid }
        elif item<arr[mid]:
            high=mid-1
        else:
            low=mid+1
    return -1
arr=[3, 4, 6, 7, 9, 12, 16, 17]
item=6
print(binary_search(arr,item))

# %%
# recursive solution - 
def bin_sol_recursive(arr,low,high,item):
    if low > high:
        return -1
    mid=(low+high)//2
    if arr[mid]==item:
        return mid
    elif item > arr[mid]:
        return bin_sol_recursive(arr,mid+1,high,item)
    return bin_sol_recursive(arr,low,mid-1,item)

arr=[3, 4, 6, 7, 9, 12, 16, 17]
item=6
bin_sol_recursive(arr,0,len(arr),6)

# %% [markdown]
# # Time Complexity :
# Best Case: O(1)
# Average Case: O(log N)
# Worst Case: O(log N)
# Auxiliary Space: O(1), If the recursive call stack is considered then the auxiliary space will be O(logN).

# %% [markdown]
# Applications of Binary Search Algorithm
# Binary search can be used as a building block for more complex algorithms used in machine learning, such as algorithms for training neural networks or finding the optimal hyperparameters for a model.

# %% [markdown]
# Advantages of Binary Search
# Binary search is faster than linear search, especially for large arrays.
# More efficient than other searching algorithms with a similar time complexity, such as interpolation search or exponential search.
# Binary search is well-suited for searching large datasets that are stored in external memory, such as on a hard drive or in the cloud.

# %% [markdown]
# Disadvantages of Binary Search
# The array should be sorted.
# Binary search requires that the data structure being searched be stored in contiguous memory locations.
# Binary search requires that the elements of the array be comparable, meaning that they must be able to be ordered.

# %% [markdown]
# # question on this
# 1. Can binary search be applied to non-numeric data?
# Yes, binary search can be applied to non-numeric data as long as there is a defined order for the elements. For example, it can be used to search for strings in alphabetical order.
# 2. When should Binary Search be used?
# Binary search should be used when searching for a target value in a sorted array, especially when the size of the array is large. It is particularly efficient for large datasets compared to linear search algorithms.
# 3.  What happens if the array is not sorted for binary search?
# If the array is not sorted, binary search may return incorrect results. It relies on the sorted nature of the array to make decisions about which half of the array to search.
